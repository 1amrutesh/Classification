# %% [markdown]
# # 16-Oct-21

# %%
import numpy as np
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('Advertising.csv')
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
sns.pairplot(data)

# %%
x = data[['TV', 'Radio', 'Newspaper']]

# %%
x[:2]
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1

# %%
vif_data = pd.DataFrame()

# %%
vif_data['Feature'] = x.columns

# %%
vif_data
# Out:
#      Feature
# 0         TV
# 1      Radio
# 2  Newspaper

# %%
vif_data['VIF'] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]

# %%
vif_data
# Out:
#      Feature       VIF
# 0         TV  2.486772
# 1      Radio  3.285462
# 2  Newspaper  3.055245

# %% [markdown]
# # 28-Sept-21

# %%
# Read & Write file operations

import numpy as np
import pandas as pd

# Reading Data
data = pd.read_csv('C:\\docs\\Sudhir\\SIT-MTECH\\Supervised Learning Lab\\a\\headbrain.csv')
print(data.head(2))
print('\n')

# Write to a file
data[['Head Size(cm^3)', 'Gender', 'Age Range']].to_csv('C:\\docs\\Sudhir\\SIT-MTECH\\Supervised Learning Lab\\a\\file1.csv', header=True, index=False)
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297

# %%
# Creating a folder

import os

parent_directory = os.getcwd()
new_directory = "b"

path = os.path.join(parent_directory, new_directory)
os.mkdir(path)
